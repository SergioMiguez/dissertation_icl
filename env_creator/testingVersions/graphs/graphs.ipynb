# %%
import matplotlib.pyplot as plt

# %%
# Benchmark titles
benchmarks = [
    "1 Ubuntu LXC", "1 Alpine LXC", "1 Debian LXC", 
    "1 Fedora LXC", "2 Parallel LXC", "3 Parallel LXC", "4 Parallel LXC"
]

# Average times
average_times = [
    5.98072, 5.97460, 5.96122, 
    5.97910, 7.20334, 8.26198, 9.78704
]

# Coefficients of interval with 95% confidence (errors)
confidence_intervals = [
    0.05444, 0.05624, 0.04332, 
    0.03785, 0.13817, 0.21162, 0.43075
]

# Plotting the data
plt.figure(figsize=(10, 6))

# Plot the average times with error bars
plt.errorbar(benchmarks, average_times, yerr=confidence_intervals, fmt='o', capsize=5, color='blue', ecolor='red', elinewidth=2, markeredgewidth=2)

# Add titles and labels
plt.title("Benchmark 50 Times Average with 95% Confidence Intervals")
plt.xlabel("Benchmark Type")
plt.ylabel("Average Time (seconds)")
plt.xticks(rotation=45, ha="right")

# Display the grid for easier readability
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', linewidth=0.5)


# Show the plot
plt.tight_layout()
plt.show()

# %%
# Benchmark titles

"""
    File: raw_benchmark
Samples: 50
Average time: 19.27108
Standard deviation: 0.781024169664422
Standard Error of the Mean (SEM): 0.11045349732806108
Coefficient of interval with 95% confidence: 0.2164888547629997
~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~


File: p_start_benchmark
Samples: 50
Average time: 12.32568
Standard deviation: 2.62113343758001
Standard Error of the Mean (SEM): 0.37068424562152624
Coefficient of interval with 95% confidence: 0.7265411214181914
~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~


File: p_clone_start_benchmark
Samples: 50
Average time: 8.11586
Standard deviation: 0.6821821753754638
Standard Error of the Mean (SEM): 0.09647512844251621
Coefficient of interval with 95% confidence: 0.18909125174733177
~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
"""

benchmarks = [
    "S clone - S launch", "S clone - P launch", "P clone - P launch"
]

# Average times
average_times = [
    19.27108, 12.32568, 8.11586
]

# Coefficients of interval with 95% confidence (errors)
confidence_intervals = [
    0.2164888547629997, 0.7265411214181914, 0.18909125174733177
]
# Plotting the data
plt.figure(figsize=(5, 5))

# Plot the average times with error bars
plt.errorbar(benchmarks, average_times, yerr=confidence_intervals, fmt='o', capsize=5, color='blue', ecolor='red', elinewidth=2, markeredgewidth=2)

# Add titles and labels
# Add titles and labels
plt.title("Average Times to Deploy 3 LXCs (Ubuntu, Debian, Fedora) with 95% Confidence Intervals")
plt.xlabel("Benchmark Title")
plt.ylabel("Average Time (seconds)")
plt.xticks(rotation=45, ha="right")

# Display the grid for easier readability
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Add subgrid
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', linewidth=0.5)

# Show the plot
plt.tight_layout()
plt.show()
